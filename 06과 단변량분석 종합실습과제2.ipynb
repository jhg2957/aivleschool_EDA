# %% [markdown]
# # 06과 단변량분석 종합실습과제

# %% [markdown]
# * 고객사는 카시트를 판매하는 회사 입니다.
# * 최근 매출 하락에 대해 각 부서가 파악한 원인 다음과 같습니다.
#     * 최근에 경쟁사와의 가격 경쟁력이 하락하고 있고, 광고비용이 적절하게 집행되지 않음
#     * 너무 국내 시장에 집중됨.
#     * 지역마다의 구매력을 제대로 파악하지 못하고 있음.
#
# * 그러나 이러한 분석은 데이터에 근거하고 있는지 의문이 듭니다.
# * 이 문제를 해결하고자 프로젝트 팀이 빌딩되었습니다.
# * 여러분은 이 프로젝트팀에 데이터분석전문가 이자 AI 개발자로 참여하고 있습니다.
# * 드디어 AIVLE 과정에서 배운 [파이썬 라이브러리 활용]과 [데이터 분석] 과정에서 갈고 닦은 실력을 발휘할 기회가 주어졌습니다.
# * 자, 이제 단변량 분석을 통해 비즈니스 인사이트를 도출해 봅시다!

# %% [markdown]
# **단변량 분석 할 때 확인해야 할 점들**
#
# * 개별 변수의 분포로 부터…
#     * 값의 범위 확인
#     * 데이터가 모여 있는 구간(혹은 범주)와 희박한 구간(혹은 범주) 확인
#     * 이상치 확인 및 조치 방안
#     * 결측치 확인 및 조치 방안
#     * 가변수화, 스케일링 대상 선별
#
# * 비즈니스의 일반 사항과 특이사항을 도출
#     * 추가 분석 대상 도출.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 카시트 판매량 데이터

# %% [markdown]
# ![](https://cdn.images.express.co.uk/img/dynamic/24/590x/child-car-seat-986556.jpg?r=1532946857754)

# %% [markdown]
# |	변수명	|	설명	|	구분	|
# |	----	|	----	|	----	|
# |	Sales 	|	 각 지역 판매량(단위 : 1000개)	|	Target	|
# |	CompPrice 	|	 경쟁사 가격(단위 : 달러)	|	feature	|
# |	Income 	|	 지역 평균 소득(단위 : 1000달러)	|	feature	|
# |	Advertising 	|	 각 지역, 회사의 광고 예산(단위 : 1000달러)	|	feature	|
# |	Population 	|	 지역 인구수(단위 : 1000명)	|	feature	|
# |	Price 	|	 자사 지역별 판매가격	|	feature	|
# |	ShelveLoc 	|	 진열상태	|	feature	|
# |	Age 	|	 지역 인구의 평균 연령	|	feature	|
# |	Urban 	|	 도심 지역 여부(0,1)	|	feature	|
# |	US 	|	 매장이 미국에 있는지 여부(0,1)	|	feature	|

# %%
path = 'https://raw.githubusercontent.com/JunhoYu/Data-Analysis/main/Carseats.csv'
data = pd.read_csv(path)
data.drop('Education', axis = 1, inplace = True)
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Urban        400 non-null    object
#  9   US           400 non-null    object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# ### ① Sales (Target)

# %%
target = 'Sales'

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# > 각 지역 판매량(단위 1000개)

# %% [markdown]
# 2) 숫자, 범주?

# %% [markdown]
# > 숫자 (float64)

# %%
print(data[target].dtype)
# Out:
# float64

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %%
data[target].isna().sum()
# Out:
# 0

# %% [markdown]
# > NaN이 존재하지 않음

# %% [markdown]
# 4) 가변수화 필요 여부

# %% [markdown]
# > 범주가 아니기에 가변수화 불가능

# %% [markdown]
# 5) 기초통계량(수치화)

# %%
data[target].describe()
# Out:
# count    400.000000
# mean       7.496325
# std        2.824115
# min        0.000000
# 25%        5.390000
# 50%        7.490000
# 75%        9.320000
# max       16.270000
# Name: Sales, dtype: float64

# %% [markdown]
# 6) 분포 확인(시각화)

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 1)
sns.histplot(data[target]).set_title('histogram')

plt.subplot(1, 2, 2)
sns.kdeplot(data[target]).set_title('KDE')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# - 지역과 무관하게 비슷한 판매량을 볼 수 있다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# - 해당 지역의 인구 대비 판매량 확인
# - carseat 관계된 법령을 확인

# %% [markdown]
# ### ② CompPrice

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# > 경쟁사 가격 (단위 : 1000$)

# %% [markdown]
# 2) 숫자, 범주?

# %%
data['CompPrice'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# > 숫자 (int 64)

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %%
data['CompPrice'].isna().sum()
# Out:
# 0

# %% [markdown]
# > 결측치가 존재하지 않는다.

# %% [markdown]
# 4) 가변수화 필요 여부

# %%
data['CompPrice'].unique().sum()
# Out:
# 9106

# %% [markdown]
# > 다양한 형태의 자료가 있기 때문에 가변수화가 불가능해 보인다.

# %% [markdown]
# 5) 기초통계량(수치화)

# %%
data['CompPrice'].describe()
# Out:
# count    400.000000
# mean     124.975000
# std       15.334512
# min       77.000000
# 25%      115.000000
# 50%      125.000000
# 75%      135.000000
# max      175.000000
# Name: CompPrice, dtype: float64

# %% [markdown]
# 6) 분포 확인(시각화)

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 1)
sns.histplot(data['CompPrice']).set_title('histogram')

plt.subplot(1, 2, 2)
sns.kdeplot(data['CompPrice']).set_title('KDE')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# > 경쟁사 가격이 판매량에 직접적인 영향은 되지 않은 것 같다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# > 해당 지역 자사 가격대비 얼마나 비싼지를 확인 해야할것 같다. (이변량 분석)

# %% [markdown]
# ### ③ Income

# %%
data['Income']
# Out:
# 0       73
# 1       48
# 2       35
# 3      100
# 4       64
#       ...
# 395    108
# 396     23
# 397     26
# 398     79
# 399     37
# Name: Income, Length: 400, dtype: int64

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# > 지역 평균 소득(단위 : 1000$)

# %% [markdown]
# 2) 숫자, 범주?

# %%
data['Income'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# > 숫자 (int64)

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %%
data['Income'].isna().sum()
# Out:
# 0

# %% [markdown]
# > 결측치 없음

# %% [markdown]
# 4) 가변수화 필요 여부

# %%
data['Income'].unique().sum()
# Out:
# 6916

# %% [markdown]
# > 다양한 수로 인해 가변수화 불가능

# %% [markdown]
# 5) 기초통계량(수치화)

# %%
data['Income'].describe()
# Out:
# count    400.000000
# mean      68.657500
# std       27.986037
# min       21.000000
# 25%       42.750000
# 50%       69.000000
# 75%       91.000000
# max      120.000000
# Name: Income, dtype: float64

# %% [markdown]
# 6) 분포 확인(시각화)

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 1)
sns.histplot(data['Income']).set_title('histogram')

plt.subplot(1, 2, 2)
sns.kdeplot(data['Income']).set_title('KDE')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# > 6만불을 기점으로 데이터가 많이 차이가 난다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# - 조사 결과 5만불을 기점으로 평균 소득이 괜찮은 편에 속한다고 한다.
# - 6만불을 기점으로 값이 많이 차이가 있다.
# - 수입이 6만불이 안되는 가구의 경우 자녀가 없는 집일 가능성도 고려를 해야한다고 생각한다.
# - 8만불 이상의 가구는 어린 자녀가 없을 수 있다.

# %% [markdown]
# ### ④ Advertising

# %%
data['Advertising']
# Out:
# 0      11
# 1      16
# 2      10
# 3       4
# 4       3
#        ..
# 395    17
# 396     3
# 397    12
# 398     7
# 399     0
# Name: Advertising, Length: 400, dtype: int64

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# > 각 지역, 회사의 광고 예산(단위: 1000$)

# %% [markdown]
# 2) 숫자, 범주?

# %%
data['Advertising'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# > 숫자(int64)

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %%
data['Advertising'].isna().sum()
# Out:
# 0

# %% [markdown]
# > 결측치 없음

# %% [markdown]
# 4) 가변수화 필요 여부

# %%
data['Advertising'].unique().sum()
# Out:
# 380

# %% [markdown]
# > 다양한 결과로 가변수화 불가능

# %% [markdown]
# 5) 기초통계량(수치화)

# %%
data['Advertising'].describe()
# Out:
# count    400.000000
# mean       6.635000
# std        6.650364
# min        0.000000
# 25%        0.000000
# 50%        5.000000
# 75%       12.000000
# max       29.000000
# Name: Advertising, dtype: float64

# %% [markdown]
# 6) 분포 확인(시각화)

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 1)
sns.histplot(data['Advertising']).set_title('histogram')

plt.subplot(1, 2, 2)
sns.kdeplot(data['Advertising']).set_title('KDE')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### ⑤ Population

# %%
data['Population']
# Out:
# 0      276
# 1      260
# 2      269
# 3      466
# 4      340
#       ...
# 395    203
# 396     37
# 397    368
# 398    284
# 399     27
# Name: Population, Length: 400, dtype: int64

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 숫자, 범주?

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %% [markdown]
# 4) 가변수화 필요 여부

# %% [markdown]
# 5) 기초통계량(수치화)

# %% [markdown]
# 6) 분포 확인(시각화)

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### ⑥ Price

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 숫자, 범주?

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %% [markdown]
# 4) 가변수화 필요 여부

# %% [markdown]
# 5) 기초통계량(수치화)

# %% [markdown]
# 6) 분포 확인(시각화)

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### ⑦ ShelveLoc

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 숫자, 범주?

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %% [markdown]
# 4) 가변수화 필요 여부

# %% [markdown]
# 5) 기초통계량(수치화)

# %% [markdown]
# 6) 분포 확인(시각화)

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### ⑧ Age

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 숫자, 범주?

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %% [markdown]
# 4) 가변수화 필요 여부

# %% [markdown]
# 5) 기초통계량(수치화)

# %% [markdown]
# 6) 분포 확인(시각화)

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### ⑨ Urban

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 숫자, 범주?

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %% [markdown]
# 4) 가변수화 필요 여부

# %% [markdown]
# 5) 기초통계량(수치화)

# %% [markdown]
# 6) 분포 확인(시각화)

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# ### ⑩ US

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %% [markdown]
# 2) 숫자, 범주?

# %% [markdown]
# 3) NaN 존재 유무 및 조치방안

# %% [markdown]
# 4) 가변수화 필요 여부

# %% [markdown]
# 5) 기초통계량(수치화)

# %% [markdown]
# 6) 분포 확인(시각화)

# %% [markdown]
# 7) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %% [markdown]
# 8) 추가 분석해 볼 사항이 있나요?
